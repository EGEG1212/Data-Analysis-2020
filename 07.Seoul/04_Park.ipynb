# %% [markdown]
# 교수님꺼는.. 서울시 주요 공원현황(수정) 뭘수정하신거지~?
#
# ## 서울시 공원현황 분석
#
#   - 공원 수 vs 구
#   - 공원 면적 vs 구 인구
#   - 공원 면적 vs 구 면적
#   - 공원 지도에 표시하기(공원 크기가 차이가 나도록)
#   - 강서구 지도에 공원 자세히 표시하기
#    \+자치구에 사용면적

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline
# 한글폰트 사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %%
import folium
import json
geo_str = json.load(open('./data/skorea_municipalities_geo_simple.json',
                         encoding='utf8'))

# %% [markdown]
# ## 데이터 파악하고 정리하기

# %%
park = pd.read_csv('./data/서울시 주요 공원현황(수정).csv', encoding='utf-8')
park.head(3)
# Out:
#    공원번호       공원명                                               공원개요  \
# 0     1  남산도시자연공원  남산공원은 도심에 위치하여 서울시민에게 맑은 공기를 제공하는 자연휴식처이며 산책 꽃...
# 1     3    길동생태공원  길동생태공원은 생물의 서식처를 제공하고 종다양성을 증진시키며 자연생태계의 생물들을 ...
# 2     4     서울대공원  서울대공원은 세계 각국의 야생동물들이 살아 숨 쉬는 서울동물원과 다양한 재미와 즐거...
#
#                           면적        개원일  \
# 0  2896887㎡ 2454140㎡ 442747㎡  1968.9.10
# 1                     80683㎡  1999.5.20
# 2                   9132690㎡   1984.5.1
#
#                                                 주요시설  \
# 0  기반시설 : 광장 45950㎡ 도로 108530㎡ 산책로 6.7㎞ (북측:3.7㎞/...
# 1               탐방객안내소 야외전시대 관찰대 목재데크 조류관찰대 길동생태문화센터
# 2  동물원 식물원 테마가든(장미원 어린이동물원 피크닉장) 치유숲 산림욕장 캠핑장 국립현...
#
#                                         주요식물  \
# 0          소나무 단풍 아카시아 상수리나무 등 191종 2881870주
# 1  소나무 보리수 등 64종 31800주 산국 부들 등 138종 192800본
# 2                                        NaN
#
#                                                  안내도  \
# 0  http://parks.seoul.go.kr/upload/seditorMulti/2...
# 1  http://parks.seoul.go.kr/template/common/img/p...
# 2                                                NaN
#
#                                                 오시는길  \
# 0  명동역(남산케이블카 와룡묘 서울애니메이션센터 방면) 도보 명동역 3번출구 → 퍼시픽...
# 1                                                NaN
# 2  지하철 4호선 대공원역 하차(2번 출구) 도보 15분 정도 문의처 02)500-73...
#
#                                              이용시참고사항  \
# 0  남산공원 차량통행 금지안내 2005년 5월 1일부터 남산공원에 일반승용차 택시 통행...
# 1  매주 월요일은 휴관입니다 사전예약 후 입장하실 수 있습니다. ▶ 인터넷 예약 바로가...
# 2  일반사항 공원을 깨끗하게 이용합니다. 대중교통을 이용해 주세요. 기념물 시설물 풀과...
#
#                                                  이미지   지역  \
# 0  http://parks.seoul.go.kr/file/info/view.do?fId...   중구
# 1  http://parks.seoul.go.kr/file/info/view.do?fId...  강동구
# 2  http://parks.seoul.go.kr/file/info/view.do?fId...  과천시
#
#                            공원주소              관리부서          전화번호  X좌표(GRS80TM)  \
# 0        서울특별시 중구 삼일대로 231(예장동)    서울특별시중부푸른도시사업소  02-3783-5900    198364.107
# 1  서울특별시 강동구 천호대로 1291(길동생태공원)   동부공원녹지사업소 길동생태공원   02-489-2770    213554.120
# 2            경기도 과천시 대공원광장로 102             전략기획실   02-500-7032    200994.267
#
#    Y좌표(GRS80TM)  X좌표(WGS84)  Y좌표(WGS84)  \
# 0    450395.554  126.990377   37.550140
# 1    448852.675  127.154779   37.540394
# 2    437163.981  127.019847   37.426449
#
#                                                바로가기
# 0   http://parks.seoul.go.kr/template/sub/namsan.do
# 1  http://parks.seoul.go.kr/template/sub/gildong.do
# 2                     http://grandpark.seoul.go.kr/

# %%
#제곱미터 떼는 함수? 
def calc_area(s):
    if s == '0':
        return 0

    num_list = s.strip().split('㎡')
    area = 0
    for num_str in num_list:
        if num_str == '':
            continue  #이어서 뭘 하겠다는건지?
        area += float(num_str)

    return area

# %%
[park['면적'].isnull()]
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  127    False
#  128    False
#  129    False
#  130    False
#  131     True
#  Name: 면적, Length: 132, dtype: bool]

# %%
park['면적'][park['면적'].isnull()] = '0'  #109,119,131 NaN  그걸 '0'으로 바꾼다는 말인가?
park['area'] = park['면적'].map(calc_area)
park[['면적','area']].head()
# Out:
#                           면적       area
# 0  2896887㎡ 2454140㎡ 442747㎡  5793774.0
# 1                     80683㎡    80683.0
# 2                   9132690㎡  9132690.0
# 3                    480994㎡   480994.0
# 4                   2284085㎡  2284085.0

# %%
#컬럼쏙쏙뽑아서 데이터프레임만듦
park_new = park[['공원명','지역','공원주소','area','공원개요']]
park_new.sort_values(by=['공원명'], inplace=True)
park_new.reset_index(inplace=True)
del park_new['index']
park_new.head()
# Out:
#             공원명    지역                            공원주소      area  \
# 0       간데메근린공원  동대문구   서울특별시 동대문구 서울시립대로2길 59(간데메공원)   15179.7
# 1        갈산근린공원   양천구            서울특별시 양천구 신정동 162-56  138596.0
# 2  감로천생태공원(관악산)   금천구                  서울 금천구 독산동 373   15000.0
# 3       개운산근린공원   성북구  서울특별시 성북구 북악산로 949-73(돈암동 6-1)  297926.0
# 4       개웅산근린공원   구로구             서울특별시 구로구 오류동 산13-1  411972.0
#
#                                                 공원개요
# 0  옛날 답십리 일대에 원말(원촌) 넘말(월촌) 간데메(중산)의 마을이 흩어져 있었는데...
# 1  용왕산의 동쪽 능선 끝이 안양천에 닿아 있는데 이 안양천을 따라 남쪽으로 내려가서 ...
# 2  감로천 생태공원내 생태연못은 도시화로 훼손되어 사라진 자연적인 습지를 대신하여 다양...
# 3  개운산공원은 1940년 3월 12일 지정된 마을동산 성격의 산지형 공원이다. 돈암동...
# 4  개웅산공원은 서울시 개봉동 일대와 오류동에 인접한 개웅마을의 지형이 움푹 들어간 관...

# %%
import requests
from urllib.parse import quote

key_fd = open('../06.RestAPI/kakaomapkey.txt', mode='r')
kmap_key = key_fd.read(100)
key_fd.close()

# %%
#공원주소로 카카오API사용해서 좌표값구하기
lat_list, lng_list = [], []
for i in park_new.index:
    try:
        url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + quote(park_new['공원주소'][i])
        result = requests.get(url,
                headers={"Authorization": "KakaoAK "+kmap_key}).json()
        lat = float(result['documents'][0]['y'])
        lng = float(result['documents'][0]['x'])
        lat_list.append(lat)
        lng_list.append(lng)
    except:
        print(park_new['공원명'][i], park_new['공원주소'][i])  #출력이되지는 않네~? 실패한게없으니까?

# %%
park_new['lat'], park_new['lng'] = lat_list, lng_list
park_new.head()
# Out:
#         공원명   지역                          공원주소       area  \
# 0  남산도시자연공원   중구        서울특별시 중구 삼일대로 231(예장동)  5793774.0
# 1    길동생태공원  강동구  서울특별시 강동구 천호대로 1291(길동생태공원)     80683.0
# 2     서울대공원  과천시            경기도 과천시 대공원광장로 102  9132690.0
# 3       서울숲  성동구    서울특별시 성동구 뚝섬로 273 (성수동1가)    480994.0
# 4     월드컵공원  마포구     서울특별시 마포구 하늘공원로 84(월드컵공원)  2284085.0
#
#                                                 공원개요        lat         lng
# 0  남산공원은 도심에 위치하여 서울시민에게 맑은 공기를 제공하는 자연휴식처이며 산책 꽃...  37.555633  126.992218
# 1  길동생태공원은 생물의 서식처를 제공하고 종다양성을 증진시키며 자연생태계의 생물들을 ...  37.539066  127.153329
# 2  서울대공원은 세계 각국의 야생동물들이 살아 숨 쉬는 서울동물원과 다양한 재미와 즐거...  37.436431  127.014098
# 3  당초 골프장 승마장 등이 있던 뚝섬일대를 주거업무 지역으로 개발할 경우 약 4조원에...  37.543070  127.041799
# 4  월드컵공원은 서울의 서쪽에 위치하여 1978년부터 1993년까지 15년간 서울시민이...  37.572327  126.881889

# %%
park_new.area.min(), park_new.area.max() #이건왜하셨을까?
# Out:
# (0.0, 10420819.08)

# %%
#이건 뭘 나타내는 표인가? 왜하셨을까?
park_new.area.plot(kind='hist')
plt.show()

# %%
#공원사이즈 분류
area_criteria = [-1, 100000, 1000000, 12000000]
labels = ['소형', '중형', '대형']
size_info = [3, 7, 15]
park_new['scale'] = pd.cut(park_new.area, area_criteria, labels=labels)  #컬럼추가 cut?
park_new['size'] = pd.cut(park_new.area, area_criteria, labels=size_info) #컬럼추가 cut?
park_new.head()
# Out:
#         공원명   지역                          공원주소       area  \
# 0  남산도시자연공원   중구        서울특별시 중구 삼일대로 231(예장동)  5793774.0
# 1    길동생태공원  강동구  서울특별시 강동구 천호대로 1291(길동생태공원)     80683.0
# 2     서울대공원  과천시            경기도 과천시 대공원광장로 102  9132690.0
# 3       서울숲  성동구    서울특별시 성동구 뚝섬로 273 (성수동1가)    480994.0
# 4     월드컵공원  마포구     서울특별시 마포구 하늘공원로 84(월드컵공원)  2284085.0
#
#                                                 공원개요        lat         lng  \
# 0  남산공원은 도심에 위치하여 서울시민에게 맑은 공기를 제공하는 자연휴식처이며 산책 꽃...  37.555633  126.992218
# 1  길동생태공원은 생물의 서식처를 제공하고 종다양성을 증진시키며 자연생태계의 생물들을 ...  37.539066  127.153329
# 2  서울대공원은 세계 각국의 야생동물들이 살아 숨 쉬는 서울동물원과 다양한 재미와 즐거...  37.436431  127.014098
# 3  당초 골프장 승마장 등이 있던 뚝섬일대를 주거업무 지역으로 개발할 경우 약 4조원에...  37.543070  127.041799
# 4  월드컵공원은 서울의 서쪽에 위치하여 1978년부터 1993년까지 15년간 서울시민이...  37.572327  126.881889
#
#   scale size
# 0    대형   15
# 1    소형    3
# 2    대형   15
# 3    중형    7
# 4    대형   15

# %%
#서울 폴리움지도 공원크기별로 서클표시
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)
for i in park_new.index:
    folium.CircleMarker([park_new.lat[i], park_new.lng[i]], 
                        radius=int(park_new['size'][i]),
                        tooltip=f"{park_new['공원명'][i]}({int(park_new.area[i])}㎡)",
                        color='#3186cc', fill_color='#3186cc').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>서울시내 공원 위치와 크기</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
for i in park_new.index:
    folium.CircleMarker([park_new.lat[i], park_new.lng[i]], 
                        radius=int(park_new['size'][i]),
                        tooltip=f"{park_new['공원명'][i]}({int(park_new.area[i])}㎡)",
                        color='green', fill_color='green').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>서울시내 공원 위치와 크기</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 자치구별 공원 분석

# %%
park_new.groupby('지역').sum()
# Out:
#              area         lat          lng
# 지역
# 강남구    3626398.50  262.485040   889.460129
# 강동구    1526389.30  262.816971   890.061105
# 강북구    3714902.40  150.576675   508.076532
# 강서구    2194154.10  338.103348  1141.556710
# 과천시    9132690.00   37.436431   127.014098
# 관악구   10431453.08   74.932366   253.897712
# 광진구     584002.00   75.103768   254.179148
# 구로구    1617657.00  149.982634   507.362957
# 금천구      57568.00  149.858797   507.630065
# 노원구   12235699.30  112.978029   381.218963
# 도봉구    1084218.00  225.945670   762.243361
# 동대문구    458663.70  150.300539   508.220571
# 동작구    3706739.10  262.488430   888.641284
# 마포구    2685112.70  187.819710   634.503652
# 서대문구   3321476.60  150.308688   507.753724
# 서초구   13359636.00  224.771072   762.258327
# 성동구     626838.70  187.738532   635.155841
# 성북구    1198327.00  112.793400   381.084864
# 송파구    2838992.80  262.520419   889.843348
# 양천구    1203428.50  187.623519   634.303554
# 영등포구    485990.00  187.621740   634.576678
# 용산구     247194.10   75.065074   253.946883
# 은평구    2986584.18  263.319725   888.407679
# 종로구    3907680.57  450.966731  1523.819824
# 중구     5840190.80  187.791646   634.910146
# 중랑구    7078975.00  225.561733   762.590924

# %%
park_new.groupby('지역').count()['area']
# Out:
# 지역
# 강남구      7
# 강동구      7
# 강북구      4
# 강서구      9
# 과천시      1
# 관악구      2
# 광진구      2
# 구로구      4
# 금천구      4
# 노원구      3
# 도봉구      6
# 동대문구     4
# 동작구      7
# 마포구      5
# 서대문구     4
# 서초구      6
# 성동구      5
# 성북구      3
# 송파구      7
# 양천구      5
# 영등포구     5
# 용산구      2
# 은평구      7
# 종로구     12
# 중구       5
# 중랑구      6
# Name: area, dtype: int64

# %%
park_gu = park_new.groupby('지역').sum()  #컬럼3개나옴 area lat lng
park_gu['공원수'] = park_new.groupby('지역').count()['area'] #컬럼추가 지역별로 area갯수count
del park_gu['lat']
del park_gu['lng']
park_gu.drop(['과천시'], inplace=True)  #과천시는 서울이 아니므로 제외
park_gu.rename(columns={'area': '공원면적'}, inplace=True)  #컬럼명변경
park_gu.head()
# Out:
#             공원면적  공원수
# 지역
# 강남구   3626398.50    7
# 강동구   1526389.30    7
# 강북구   3714902.40    4
# 강서구   2194154.10    9
# 관악구  10431453.08    2

# %% [markdown]
# ## 구별 공원수

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data = geo_str,
               data = park_gu['공원수'],
               columns = [park_gu.index, park_gu['공원수']],
               fill_color = 'PuRd',
               key_on = 'feature.id')
for i in park_new.index:
    folium.CircleMarker([park_new.lat[i], park_new.lng[i]], 
                        radius=int(park_new['size'][i]),
                        tooltip=f"{park_new['공원명'][i]}({int(park_new.area[i])}㎡)",
                        color='green', fill_color='green').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>자치구별 공원수</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 구별 공원면적

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data = geo_str,
               data = park_gu['공원면적'],
               columns = [park_gu.index, park_gu['공원면적']],
               fill_color = 'PuRd',
               key_on = 'feature.id')
for i in park_new.index:
    folium.CircleMarker([park_new.lat[i], park_new.lng[i]], 
                        radius=int(park_new['size'][i]),
                        tooltip=f"{park_new['공원명'][i]}({int(park_new.area[i])}㎡)",
                        color='green', fill_color='green').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>자치구별 공원면적</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 자치구별 공원면적 비율

# %%
df = pd.read_csv('./data/서울시 자치구 면적(2019).tsv', sep='\t', header=1)
df.drop([0], inplace=True)
del df['기간']
df.set_index('자치구', inplace=True)
df.head()
# Out:
#         면적  구성비(%)  행정  법정    통      반
# 자치구
# 종로구  23.91     4.0  17  87  278  1,479
# 중구    9.96     1.6  15  74  253  1,580
# 용산구  21.87     3.6  16  36  351  2,550
# 성동구  16.86     2.8  17  17  466  3,619
# 광진구  17.06     2.8  15   7  363  2,999

# %%
park_gu['구면적'] = df['면적'] * 1000000
park_gu.head()
# Out:
#             공원면적  공원수         구면적
# 지역
# 강남구   3626398.50    7  39500000.0
# 강동구   1526389.30    7  24590000.0
# 강북구   3714902.40    4  23600000.0
# 강서구   2194154.10    9  41440000.0
# 관악구  10431453.08    2  29570000.0

# %%
park_gu['공원면적비율'] = park_gu['공원면적'] / park_gu['구면적'] * 100
park_gu['공원면적비율'].sort_values().plot(kind='barh', grid=True, figsize=(12,8))
plt.title('구별 공원면적비율')
plt.show()

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data = geo_str,
               data = park_gu['공원면적비율'],
               columns = [park_gu.index, park_gu['공원면적비율']],
               fill_color = 'PuRd',
               key_on = 'feature.id')
for i in park_new.index:
    folium.CircleMarker([park_new.lat[i], park_new.lng[i]], 
                        radius=int(park_new['size'][i]),
                        tooltip=f"{park_new['공원명'][i]}({int(park_new.area[i])}㎡)",
                        color='green', fill_color='green').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>자치구별 공원면적 비율</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 자치구별 인당 공원면적

# %%
df = pd.read_csv('./results/01.cctv.csv')
df.set_index('구별', inplace=True)
df.head()
# Out:
#        소계      최근증가율     인구수     내국인    외국인    고령자     외국인비율      고령자비율  \
# 구별
# 강남구  5221  52.171379  544085  539235   4850  73942  0.891405  13.590156
# 강동구  1879  82.960078  462275  458058   4217  68798  0.912228  14.882483
# 강북구  1265  83.068017  313550  309996   3554  62951  1.133472  20.076862
# 강서구  1617  77.887789  589536  583544   5992  88052  1.016393  14.935814
# 관악구  3985  99.150425  514555  498574  15981  78206  3.105790  15.198764
#
#        cctv비율           오차
# 구별
# 강남구  0.959593  2579.013268
# 강동구  0.406468   526.315431
# 강북구  0.403444   710.063146
# 강서구  0.274284  1156.473682
# 관악구  0.774456  1428.441743

# %%
park_gu['인구수'] = df['인구수']
park_gu['인당공원면적'] = park_gu['공원면적'] / park_gu['인구수']
park_gu.head()
# Out:
#             공원면적  공원수         구면적     공원면적비율     인구수     인당공원면적
# 지역
# 강남구   3626398.50    7  39500000.0   9.180756  544085   6.665132
# 강동구   1526389.30    7  24590000.0   6.207358  462275   3.301908
# 강북구   3714902.40    4  23600000.0  15.741112  313550  11.847879
# 강서구   2194154.10    9  41440000.0   5.294773  589536   3.721832
# 관악구  10431453.08    2  29570000.0  35.277149  514555  20.272766

# %%
park_gu['인당공원면적'].sort_values().plot(kind='barh', grid=True, figsize=(12,8))
plt.title('구별 인당 공원면적')
plt.show()

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data = geo_str,
               data = park_gu['인당공원면적'],
               columns = [park_gu.index, park_gu['인당공원면적']],
               fill_color = 'PuRd',
               key_on = 'feature.id')
for i in park_new.index:
    folium.CircleMarker([park_new.lat[i], park_new.lng[i]], 
                        radius=int(park_new['size'][i]),
                        tooltip=f"{park_new['공원명'][i]}({int(park_new.area[i])}㎡)",
                        color='green', fill_color='green').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>자치구별 인당 공원면적</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 생활환경 만족도

# %%
df = pd.read_csv('./data/서울시 생활환경 만족도(2019).tsv', sep='\t')

# %%
df
# Out:
#       기간    대분류           분류  주거환경  경제환경  사회환경  교육환경
# 0   2019    서울시          서울시  6.39  5.50  6.00  5.71
# 1   2019     성별           남자  6.39  5.57  6.00  5.73
# 2   2019     성별           여자  6.39  5.34  6.02  5.67
# 3   2019    연령별       20대 이하  6.48  5.13  6.00  5.73
# 4   2019    연령별          30대  6.33  5.62  5.99  5.73
# 5   2019    연령별          40대  6.33  5.56  5.95  5.72
# 6   2019    연령별          50대  6.35  5.60  5.97  5.65
# 7   2019    연령별       60대 이상  6.45  5.45  6.05  5.73
# 8   2019    학력별        중졸 이하  6.42  5.16  6.04  5.62
# 9   2019    학력별        고졸 이하  6.38  5.53  6.00  5.72
# 10  2019    학력별         대졸이하  6.39  5.60  6.00  5.75
# 11  2019    학력별       대학원 이상  6.42  5.62  5.72  5.54
# 12  2019   주택형태         단독주택  6.30  5.38  5.90  5.74
# 13  2019   주택형태          아파트  6.52  5.67  6.10  5.75
# 14  2019   주택형태        다세대주택  6.26  5.35  5.94  5.55
# 15  2019   주택형태        연립/기타  6.34  5.46  6.00  5.78
# 16  2019   입주형태           자가  6.46  5.66  5.99  5.68
# 17  2019   입주형태           전세  6.36  5.51  5.97  5.75
# 18  2019   입주형태        월세/기타  6.33  5.30  6.05  5.74
# 19  2019   가구원수           1인  6.39  5.34  6.03  5.75
# 20  2019   가구원수           2인  6.45  5.57  6.04  5.75
# 21  2019   가구원수           3인  6.32  5.56  5.91  5.61
# 22  2019   가구원수           4인  6.36  5.63  5.99  5.65
# 23  2019   가구원수        5인 이상  6.55  5.55  6.08  5.92
# 24  2019     소득    100 만원 미만  6.29  4.81  5.95  5.56
# 25  2019     소득  100-200만 미만  6.26  5.00  5.91  5.62
# 26  2019     소득  200-300만 미만  6.45  5.44  5.99  5.71
# 27  2019     소득  300-400만 미만  6.47  5.74  6.08  5.84
# 28  2019     소득  400-500만 미만  6.25  5.53  6.00  5.70
# 29  2019     소득     500만원 이상  6.45  5.73  6.01  5.72
# 30  2019  지역대분류          도심권  6.30  5.56  6.02  5.91
# 31  2019  지역대분류          동북권  6.31  5.44  5.96  5.63
# 32  2019  지역대분류          서북권  6.41  5.43  6.08  5.76
# 33  2019  지역대분류          서남권  6.43  5.52  5.93  5.67
# 34  2019  지역대분류          동남권  6.47  5.62  6.13  5.84
# 35  2019    종로구          종로구  6.43  5.68  5.99  5.98
# 36  2019     중구           중구  6.39  5.22  5.89  5.53
# 37  2019    용산구          용산구  6.16  5.67  6.11  6.09
# 38  2019    성동구          성동구  6.47  5.42  5.92  5.84
# 39  2019    광진구          광진구  6.68  5.78  6.38  5.97
# 40  2019   동대문구         동대문구  6.43  5.80  6.04  5.39
# 41  2019    중랑구          중랑구  6.39  5.60  6.21  5.96
# 42  2019    성북구          성북구  5.99  5.10  5.60  5.31
# 43  2019    강북구          강북구  6.20  5.02  5.67  5.41
# 44  2019    도봉구          도봉구  6.45  5.52  5.87  5.75
# 45  2019    노원구          노원구  6.07  5.30  5.98  5.48
# 46  2019    은평구          은평구  6.19  5.25  5.90  5.55
# 47  2019   서대문구         서대문구  6.38  5.29  6.19  5.78
# 48  2019    마포구          마포구  6.69  5.76  6.19  6.00
# 49  2019    양천구          양천구  6.44  5.71  5.69  5.64
# 50  2019    강서구          강서구  6.11  5.29  6.12  5.65
# 51  2019    구로구          구로구  6.63  5.63  6.12  5.84
# 52  2019    금천구          금천구  6.08  5.32  5.59  5.32
# 53  2019   영등포구         영등포구  6.34  5.74  5.87  5.75
# 54  2019    동작구          동작구  6.54  5.18  6.05  5.70
# 55  2019    관악구          관악구  6.71  5.72  5.88  5.68
# 56  2019    서초구          서초구  6.65  5.69  5.91  5.76
# 57  2019    강남구          강남구  6.40  5.48  6.15  5.96
# 58  2019    송파구          송파구  6.67  5.84  6.38  6.03
# 59  2019    강동구          강동구  6.09  5.39  5.91  5.47

# %%
df = pd.read_csv('./data/서울시 생활환경 만족도(2019).tsv', sep='\t')
del df['기간']  #컬럼삭제
del df['대분류']  #컬럼삭제
rows = list(range(35)) #앞에 34까지 필요없어서 range만들어서
df.drop(rows, inplace=True) #34줄 삭제
df.set_index('분류', inplace=True)  #분류에 구명이 있어서 셋인덱스
df.head()
# Out:
#      주거환경  경제환경  사회환경  교육환경
# 분류
# 종로구  6.43  5.68  5.99  5.98
# 중구   6.39  5.22  5.89  5.53
# 용산구  6.16  5.67  6.11  6.09
# 성동구  6.47  5.42  5.92  5.84
# 광진구  6.68  5.78  6.38  5.97

# %%
#주거환경 만족도 관악구, 마포구, 광진구,송파구,서초구 높다
df['주거환경'].sort_values().plot(kind='barh', grid=True, figsize=(12,8))
plt.title('구별 주거환경 만족도')
plt.show()

# %%
#컬럼추가
park_gu['주거환경만족도'] = df['주거환경']
park_gu['인당공원면적비율'] = park_gu['인당공원면적'] / park_gu['인당공원면적'].values.max() \
                                * park_gu['주거환경만족도'].values.max()
park_gu.head()
# Out:
#             공원면적  공원수         구면적     공원면적비율     인구수     인당공원면적  주거환경만족도  \
# 지역
# 강남구   3626398.50    7  39500000.0   9.180756  544085   6.665132     6.40
# 강동구   1526389.30    7  24590000.0   6.207358  462275   3.301908     6.09
# 강북구   3714902.40    4  23600000.0  15.741112  313550  11.847879     6.20
# 강서구   2194154.10    9  41440000.0   5.294773  589536   3.721832     6.11
# 관악구  10431453.08    2  29570000.0  35.277149  514555  20.272766     6.71
#
#      인당공원면적비율
# 지역
# 강남구  1.036262
# 강동구  0.513364
# 강북구  1.842049
# 강서구  0.578652
# 관악구  3.151909

# %%
park_gu['인당공원면적'].values.max()
# Out:
# 43.15805233481869

# %%
park_gu['주거환경만족도'].values.max()
# Out:
# 6.71

# %%
park_gu[['인당공원면적비율','주거환경만족도']].plot(kind='barh', grid=True, figsize=(12,8))
plt.title('주거환경만족도와 인당 공원면적')
plt.show()

# %% [markdown]
# ## 초미세먼지 vs 공원

# %%
df = pd.read_csv('./data/서울시 초미세먼지(2019).csv')
df.drop([0], inplace=True)
df.set_index('구분', inplace=True)
df.head()
# Out:
#      1월  2월  3월  4월  5월  6월  7월  8월  9월  10월  11월  12월
# 구분
# 강남구  43  40  46  18  26  16  18  16  11   14   20   27
# 강동구  42  39  44  18  27  18  19  18  13   17   25   36
# 강북구  39  36  42  16  25  17  19  17  13   17   21   31
# 강서구  37  35  46  19  27  18  21  19  14   18   26   30
# 관악구  41  39  49  27  34  23  14  12  11   15   19   27

# %%
#컬럼추가
df['초미세먼지'] = df.mean(axis=1) #가로방향평균
df.head()
# Out:
#      1월  2월  3월  4월  5월  6월  7월  8월  9월  10월  11월  12월      초미세먼지
# 구분
# 강남구  43  40  46  18  26  16  18  16  11   14   20   27  24.583333
# 강동구  42  39  44  18  27  18  19  18  13   17   25   36  26.333333
# 강북구  39  36  42  16  25  17  19  17  13   17   21   31  24.416667
# 강서구  37  35  46  19  27  18  21  19  14   18   26   30  25.833333
# 관악구  41  39  49  27  34  23  14  12  11   15   19   27  25.916667

# %%
df['초미세먼지'].sort_values().plot(kind='barh', grid=True, figsize=(12,8))
plt.title('구별 초미세먼지')
plt.show()

# %%
park_gu['초미세먼지'] = df['초미세먼지']
np.corrcoef(park_gu['공원면적비율'], park_gu['초미세먼지'])
# Out:
# array([[ 1.        , -0.17052509],
#        [-0.17052509,  1.        ]])

# %%
# 공원면적비율과 초미세먼지의 산점도
plt.figure(figsize=(6,6))
plt.scatter(park_gu['공원면적비율'], park_gu['초미세먼지'], s=50)
plt.grid(True)
plt.title('공원면적비율과 초미세먼지')
plt.xlabel('공원면적비율')
plt.ylabel('초미세먼지')
plt.show()

# %%
fp1 = np.polyfit(park_gu['공원면적비율'], park_gu['초미세먼지'], 1)
fx = np.array([0, 60])
f1 = np.poly1d(fp1)
fy = f1(fx)
fy
# Out:
# array([24.99090475, 23.758434  ])

# %%
park_gu['오차'] = np.abs(park_gu['초미세먼지'] - f1(park_gu['공원면적비율']))
park_sort = park_gu.sort_values('오차', ascending=False)
park_sort.head()
# Out:
#              공원면적  공원수         구면적     공원면적비율     인구수     인당공원면적  주거환경만족도  \
# 지역
# 영등포구    485990.00    5  24550000.0   1.979593  405982   1.197073     6.34
# 성북구    1198327.00    3  24570000.0   4.877196  449871   2.663712     5.99
# 도봉구    1084218.00    6  20660000.0   5.247909  329300   3.292493     6.45
# 종로구    3907680.57   12  23910000.0  16.343290  159842  24.447145     6.43
# 노원구   12235699.30    3  35440000.0  34.525111  529532  23.106629     6.07
#
#       인당공원면적비율      초미세먼지        오차
# 지역
# 영등포구  0.186115  28.833333  3.883092
# 성북구   0.414141  21.833333  3.057388
# 도봉구   0.511901  22.166667  2.716440
# 종로구   3.800921  22.666667  1.988528
# 노원구   3.592504  26.250000  1.968282

# %%
plt.figure(figsize=(14,10))
plt.scatter(park_gu['공원면적비율'], park_gu['초미세먼지'], c=park_gu['오차'], s=50)
plt.plot(fx, fy, ls='dashed', lw=3, color='g')

for i in range(10): 
    plt.text(park_sort['공원면적비율'][i]+0.6, park_sort['초미세먼지'][i]-0.05,
             park_sort.index[i], fontsize=15)

plt.grid(True)
plt.title('공원면적비율과 초미세먼지', fontsize=20)
plt.xlabel('공원면적비율')
plt.ylabel('초미세먼지')
plt.colorbar()
plt.show()

# %%
park_gu.to_csv('./results/04.park_gu.csv')

# %% [markdown]
# ## 강서구 공원 현황

# %%
addr = '서울특별시 강서구 화곡로 302 (화곡동)'      # 강서구청
url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+quote(addr)
result = requests.get(url,
            headers={"Authorization": "KakaoAK "+kmap_key}).json()
lat = float(result['documents'][0]['y'])
lng = float(result['documents'][0]['x'])
lat, lng
# Out:
# (37.5509655144007, 126.849532173376)

# %%
map = folium.Map(location=[37.5509655, 126.849532], zoom_start=13)
gangseogu = park_new[park_new['지역'] == '강서구']
for i in gangseogu.index:
    folium.CircleMarker([gangseogu.lat[i], gangseogu.lng[i]], 
                        radius=int(gangseogu['size'][i])*3,
                        tooltip=f"{gangseogu['공원명'][i]}({int(gangseogu.area[i])}㎡)",
                        color='#3186cc', fill_color='#3186cc').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>강서구 공원 현황</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
