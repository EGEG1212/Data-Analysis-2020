# %%
import requests
from urllib.parse import urlparse
import pandas as pd
import folium

# %%
folium.__version__
# Out:
# '0.11.0'

# %%
df = pd.read_csv('커피업소정보.txt', encoding='euc-kr')

# %%
df.describe()
# Out:
#              상가업소번호          시도코드         시군구코드         행정동코드         법정동코드  \
# count  9.325300e+04  93253.000000  93253.000000  9.325300e+04  9.325300e+04
# mean   1.851832e+07     33.582491  33903.236132  3.390378e+09  3.390338e+09
# std    5.257161e+06     13.085771  13041.207283  1.304115e+09  1.304124e+09
# min    2.895912e+06     11.000000  11110.000000  1.111052e+09  1.111010e+09
# 25%    1.263803e+07     27.000000  27110.000000  2.711056e+09  2.711011e+09
# 50%    1.629364e+07     41.000000  41173.000000  4.117361e+09  4.117310e+09
# 75%    2.335419e+07     44.000000  44133.000000  4.413358e+09  4.413311e+09
# max    2.852484e+07     50.000000  50130.000000  5.013062e+09  5.013032e+09
#
#                지번코드        대지구분코드         지번본번지         지번부번지         도로명코드  \
# count  9.325300e+04  93253.000000  93253.000000  72983.000000  9.325300e+04
# mean   3.390339e+18      1.004515    584.950125     19.432580  3.390358e+11
# ...

# %%
df
# Out:
#          상가업소번호              상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0      19911397    커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12
# 1      20020124            스완카페트         NaN         Q       음식       Q12
# 2      19973708               왕실         NaN         Q       음식       Q12
# 3      20004707              커피빈      코리아교대점         Q       음식       Q12
# 4      19993199     고려대학교교육관쎄리오점         NaN         Q       음식       Q12
# ...         ...              ...         ...       ...      ...       ...
# 93248  16309629  간단하지만특별한화피디Cafe      홍매뜨락마을         Q       음식       Q12
# 93249  16309593           투썸플레이스       전주평화점         Q       음식       Q12
# 93250  16309552           투썸플레이스    서산테크노밸리점         Q       음식       Q12
# 93251  16308545           우리들이야기         NaN         Q       음식       Q12
# 93252  16306530            테이블웍스         NaN         Q       음식       Q12
#
#       상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# ...

# %%
df.drop(["상가업소번호","상권업종대분류코드","상권업종대분류명","상권업종중분류코드","상권업종소분류코드","표준산업분류코드","건물관리번호","구우편번호","신우편번호","동정보","층정보","호정보"], axis=1)
# Out:
#                    상호명         지점명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도코드  \
# 0        커피빈코리아선릉로93길점  코리아선릉로93길점   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    11
# 1                스완카페트         NaN   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    11
# 2                   왕실         NaN   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    11
# 3                  커피빈      코리아교대점   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    11
# 4         고려대학교교육관쎄리오점         NaN   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    11
# ...                ...         ...      ...          ...       ...   ...
# 93248  간단하지만특별한화피디Cafe      홍매뜨락마을   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    46
# 93249           투썸플레이스       전주평화점   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    45
# 93250           투썸플레이스    서산테크노밸리점   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    44
# 93251           우리들이야기         NaN   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    46
# 93252            테이블웍스         NaN   커피점/카페  커피전문점/카페/다방  비알콜 음료점업    45
#
#          시도명  시군구코드     시군구명       행정동코드  ... 지번부번지  \
# ...

# %%
is_seoul = df['시도명'] == '서울특별시'

# %%
is_gs = df['시군구명'] == '강서구'

# %%
gs_cafe = df[is_seoul & is_gs] #서울 강서구에있는 카페742개
gs_cafe.to_csv('강서구카페.csv', sep=',', index=False)

# %%
gs_cafe[gs_cafe['상호명'].str.contains('투썸플레이스|스타벅스|이디야')]
# Out:
#          상가업소번호     상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 73     20083359  투썸플레이스   NaN         Q       음식       Q12   커피점/카페    Q12A01
# 100    20770737  투썸플레이스   NaN         Q       음식       Q12   커피점/카페    Q12A01
# 105    20680344  투썸플레이스   NaN         Q       음식       Q12   커피점/카페    Q12A01
# 110    20609296  투썸플레이스   등촌점         Q       음식       Q12   커피점/카페    Q12A01
# 172    23306719  투썸플레이스   NaN         Q       음식       Q12   커피점/카페    Q12A01
# ...         ...     ...   ...       ...      ...       ...      ...       ...
# 22962  16184630  투썸플레이스   방화동         Q       음식       Q12   커피점/카페    Q12A01
# 22972  16182786  투썸플레이스   두드림         Q       음식       Q12   커피점/카페    Q12A01
# 22978  16182694  투썸플레이스  넬비코로         Q       음식       Q12   커피점/카페    Q12A01
# 23055  16291240  투썸플레이스   NaN         Q       음식       Q12   커피점/카페    Q12A01
# 23056  16297432  투썸플레이스   NaN         Q       음식       Q12   커피점/카페    Q12A01
#
# ...

# %%
is_twosome = gs_cafe['상호명'] == '투썸플레이스'
is_twosome
# Out:
# 73       True
# 100      True
# 105      True
# 110      True
# 172      True
#          ...
# 22962    True
# 22972    True
# 22978    True
# 23055    True
# 23056    True
# Name: 상호명, Length: 742, dtype: bool

# %%
 gs_cafe.str.contains('스타벅스|STAR')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-055feab89b46> in <module>
# ----> 1 gs_cafe.str.contains('스타벅스|STAR')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
gs_cafe_star = df[gs_cafe & is_star]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     287             try:
# --> 288                 result = libops.scalar_binop(x, y, op)
#     289             except (
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_binop()
#
# ...

# %%
gs_cafe
# Out:
#          상가업소번호              상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 73     20083359   롯데시네마김포공항엔제리너스   NaN         Q       음식       Q12   커피점/카페
# 100    20770737             드림커피   NaN         Q       음식       Q12   커피점/카페
# 105    20680344             카페레인   NaN         Q       음식       Q12   커피점/카페
# 110    20609296            카페샤빌레   등촌점         Q       음식       Q12   커피점/카페
# 172    23306719        커피,와+,버블티   NaN         Q       음식       Q12   커피점/카페
# ...         ...              ...   ...       ...      ...       ...      ...
# 22962  16184630            커피볶는집   방화동         Q       음식       Q12   커피점/카페
# 22972  16182786  간단하지만특별한화피디Cafe   두드림         Q       음식       Q12   커피점/카페
# 22978  16182694  간단하지만특별한화피디Cafe  넬비코로         Q       음식       Q12   커피점/카페
# 23055  16291240             코코커피   NaN         Q       음식       Q12   커피점/카페
# 23056  16297432              레드캣   NaN         Q       음식       Q12   커피점/카페
#
# ...

# %%
seoul = df[is_seoul]  #서울에만 있는 카페18341개

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-45-342fdea688c8> in <module>
# ----> 1 star = df[is_star]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2841         # check_bool_indexer will throw exception if Series key cannot
#    2842         # be reindexed to match DataFrame rows
# -> 2843         key = check_bool_indexer(self.index, key)
#    2844         indexer = key.nonzero()[0]
#    2845         return self._take_with_is_copy(indexer, axis=0)
#
# ...

# %%
df2 = df[df['지번주소'].isin(['서울특별시 강서구'])]  
df2
# Out:
# Empty DataFrame
# Columns: [상가업소번호, 상호명, 지점명, 상권업종대분류코드, 상권업종대분류명, 상권업종중분류코드, 상권업종중분류명, 상권업종소분류코드, 상권업종소분류명, 표준산업분류코드, 표준산업분류명, 시도코드, 시도명, 시군구코드, 시군구명, 행정동코드, 행정동명, 법정동코드, 법정동명, 지번코드, 대지구분코드, 대지구분명, 지번본번지, 지번부번지, 지번주소, 도로명코드, 도로명, 건물본번지, 건물부번지, 건물관리번호, 건물명, 도로명주소, 구우편번호, 신우편번호, 동정보, 층정보, 호정보, 경도, 위도]
# Index: []
#
# [0 rows x 39 columns]

# %%
df2.to_csv('gscafe1.csv', sep=',', encoding='utf8', index=False)
