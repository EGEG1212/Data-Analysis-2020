# %% [markdown]
# # 커피 지수
# ### - (스타벅스 + 커피빈) / (이디야 + 빽다방)
# ### - 2020년 9월 데이터 (공공데이터포털/소상공인시장진흥공단_상가(상권)정보)

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline
# 한글폰트 사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %%
df = pd.read_csv('./data/소상공인시장진흥공단_상가(상권)정보_경기_202009.csv', sep='|')
df = df[df['상권업종중분류코드'] == 'Q12']
df.head()
# Out:
#       상가업소번호        상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 30  20354305  토프레소안산본오점  안산본오점         Q       음식       Q12   커피점/카페
# 33  20118383       장미다방    NaN         Q       음식       Q12   커피점/카페
# 34  20126067       바다다방    NaN         Q       음식       Q12   커피점/카페
# 50  20245440        캔모아    NaN         Q       음식       Q12   커피점/카페
# 61  20377876         알로    NaN         Q       음식       Q12   커피점/카페
#
#    상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 30    Q12A01  커피전문점/카페/다방   I56220  ...  4127110400108800007013599
# 33    Q12A01  커피전문점/카페/다방   I56220  ...  4173031021106040047052440
# 34    Q12A01  커피전문점/카페/다방   I56220  ...  4173025023101400002027939
# 50    Q12A03     생과일주스전문점   I56220  ...  4119510800112890000000002
# 61    Q12A01  커피전문점/카페/다방   I56220  ...  4136010200106080000005305
#
#                건물명                도로명주소     구우편번호    신우편번호  동정보  층정보  호정보  \
# 30             NaN  경기도 안산시 상록구 샘골로 129  426180.0  15540.0  NaN    2  NaN
# 33             NaN  경기도 여주시 점동면 청안로 117  469872.0  12667.0  NaN    1  NaN
# 34             NaN       경기도 여주시 우암로 43  469103.0  12627.0  NaN    1  NaN
# 50          팰리스카운티      경기도 부천시 중동로 108  420020.0  14613.0  NaN  NaN    1
# 61  평내마을중흥에스클레스아파트     경기도 남양주시 의안로 176  472799.0  12227.0  NaN    1  NaN
#
#             경도         위도
# 30  126.862737  37.295389
# 33  127.661380  37.205138
# 34  127.631956  37.295045
# 50  126.766971  37.491796
# 61  127.242597  37.643982
#
# [5 rows x 39 columns]

# %%
df = df[['상호명', '지점명', '도로명주소', '경도', '위도']]
df.head()
# Out:
#           상호명    지점명                도로명주소          경도         위도
# 30  토프레소안산본오점  안산본오점  경기도 안산시 상록구 샘골로 129  126.862737  37.295389
# 33       장미다방    NaN  경기도 여주시 점동면 청안로 117  127.661380  37.205138
# 34       바다다방    NaN       경기도 여주시 우암로 43  127.631956  37.295045
# 50        캔모아    NaN      경기도 부천시 중동로 108  126.766971  37.491796
# 61         알로    NaN     경기도 남양주시 의안로 176  127.242597  37.643982

# %%
sb = df[df['상호명'].str.find('스타벅스') >= 0]
sb.head()
# Out:
#                상호명      지점명                   도로명주소          경도         위도
# 2138          스타벅스   수원이마트점    경기도 수원시 권선구 경수대로 270  127.020088  37.250102
# 14412         스타벅스      NaN  경기도 김포시 김포한강11로 288-24  126.683329  37.654247
# 15487         스타벅스   현대킨텍스점    경기도 고양시 일산서구 호수로 817  126.751616  37.667982
# 17623       스타벅스정자      정자점    경기도 성남시 분당구 정자일로 166  127.106292  37.364880
# 33068  스타벅스평촌역사거리점  평촌역사거리점    경기도 안양시 동안구 시민대로 311  126.964668  37.396082

# %%
sb1 = df[df['상호명'].str.upper().str.find('STARBUCKS') >= 0]
sb1.head()
# Out:
#                     상호명  지점명                     도로명주소          경도         위도
# 267021  STARBUCKSCOFFEE  NaN            경기도 의정부시 행복로 7  127.048140  37.739587
# 423970  STARBUCKSCOFFEE  NaN  경기도 성남시 분당구 판교역로192번길 14  127.111395  37.397375

# %%
cb = df[df['상호명'].str.find('커피빈') >= 0]
cb.head()
# Out:
#                  상호명         지점명                    도로명주소          경도  \
# 11198            커피빈         NaN           경기도 이천시 남천로 93  127.447687
# 17739            커피빈    코리아수원인계점      경기도 수원시 팔달구 권광로 195  127.032669
# 30371  커피빈코리아일산원마운트점  코리아일산원마운트점   경기도 고양시 일산서구 한류월드로 300  126.754507
# 50451            커피빈  코리아죽전단국대앞점  경기도 용인시 수지구 죽전로168번길 18  127.124881
# 52943            커피빈    코리아분당수내점  경기도 성남시 분당구 황새울로214번길 8  127.112300
#
#               위도
# 11198  37.276730
# 17739  37.264938
# 30371  37.664544
# 50451  37.324407
# 52943  37.378126

# %%
cb1 = df[df['상호명'].str.find('COFFEEBEAN') >= 0]
cb1.head()
# Out:
#                    상호명  지점명                도로명주소          경도         위도
# 359577  COFFEEBEANS연천점  연천점  경기도 연천군 연천읍 연천로 256  127.074831  38.099611

# %%
ed = df[df['상호명'].str.find('이디야') >= 0]
ed.head()
# Out:
#               상호명    지점명                도로명주소          경도         위도
# 2649        이디야커피    NaN   경기도 안양시 만안구 양화로 34  126.914210  37.396684
# 10046      이디야커피숍    NaN  경기도 화성시 10용사로 343-2  127.055810  37.199417
# 13985  이디야커피가현초교점  가현초교점    경기도 김포시 김포한강2로 96  126.672792  37.638866
# 15044       이디야커피    NaN       경기도 김포시 중구로 23  126.712012  37.623389
# 16441       이디야커피    NaN      경기도 김포시 사우중로 15  126.716790  37.616963

# %%
ed1 = df[df['상호명'].str.upper().str.find('EDIYA') >= 0]
ed1.head()
# Out:
#                         상호명  지점명                 도로명주소          경도         위도
# 294528          EDIYACOFFEE  NaN       경기도 광명시 오리로 974  126.855169  37.479564
# 405340          EDIYAcoffee  NaN  경기도 고양시 일산서구 경의로 672  126.769461  37.682127
# 408409          EDIYACOFFEE  NaN       경기도 군포시 번영로 504  126.933166  37.358093
# 422391  이디야판교중앙점EDIYACOFFEE  NaN  경기도 성남시 분당구 판교역로 182  127.110045  37.396932
# 427979              EDIYA커피  NaN   경기도 가평군 가평읍 가화로 104  127.514301  37.828947

# %%
bd = df[df['상호명'].str.find('빽다방') >= 0]
bd.head()
# Out:
#               상호명      지점명                  도로명주소          경도         위도
# 13535  빽다방부천심곡대성점  부천심곡대성점         경기도 부천시 부천로 79  126.784086  37.491433
# 15255         빽다방  부천상지초교점   경기도 부천시 장말로199번길 6-4  126.764271  37.492975
# 17021         빽다방    안양비산점   경기도 안양시 동안구 관악대로 177  126.943776  37.399204
# 39463         빽다방  단대오거리역점   경기도 성남시 중원구 산성대로 354  127.155655  37.443915
# 39486  빽다방김포장기쌍용점  김포장기쌍용점  경기도 김포시 김포한강2로23번길 50  126.679620  37.641015

# %%
bd1 = df[df['상호명'].str.upper().str.find('PAIKSCOFFEE') >= 0]
bd1.head()
# Out:
# Empty DataFrame
# Columns: [상호명, 지점명, 도로명주소, 경도, 위도]
# Index: []

# %% [markdown]
# ## 모든 광역시도(17개파일)에 적용

# %%
starbucks = pd.DataFrame(columns=['상호명', '지점명', '도로명주소', '경도', '위도'])
coffeebean = pd.DataFrame(columns=['상호명', '지점명', '도로명주소', '경도', '위도'])
ediya = pd.DataFrame(columns=['상호명', '지점명', '도로명주소', '경도', '위도'])
paik = pd.DataFrame(columns=['상호명', '지점명', '도로명주소', '경도', '위도'])

# %%
from glob import glob
data_files = glob('./data/소상공인시장진흥공단_상가(상권)정보*.csv')

for filename in data_files:
    print(filename)
    df = pd.read_csv(filename, sep='|', encoding='utf8')
    df = df[df['상권업종중분류코드'] == 'Q12']
    df = df[['상호명', '지점명', '도로명주소', '경도', '위도']]

    sb = df[df['상호명'].str.contains('스타벅스|STARBUCKS|스타박스', case=False)]
    cb = df[df['상호명'].str.contains('커피빈|COFFEEBEAN', case=False)]
    ed = df[df['상호명'].str.contains('이디야|EDIYA|이디아', case=False)]
    bd = df[df['상호명'].str.contains('빽다방|PAIKSCOFFEE', case=False)]
    """ sb = df[df['상호명'].str.find('스타벅스') >= 0]
    sb1 = df[df['상호명'].str.upper().str.find('STARBUCKS') >= 0]
    cb = df[df['상호명'].str.find('커피빈') >= 0]
    cb1 = df[df['상호명'].str.upper().str.find('COFFEEBEAN') >= 0]
    ed = df[df['상호명'].str.find('이디야') >= 0]
    ed1 = df[df['상호명'].str.upper().str.find('EDIYA') >= 0]
    bd = df[df['상호명'].str.find('빽다방') >= 0]
    bd1 = df[df['상호명'].str.upper().str.find('PAIKSCOFFEE') >= 0] """

    starbucks = pd.concat([starbucks, sb])
    coffeebean = pd.concat([coffeebean, cb])
    ediya = pd.concat([ediya, ed])
    paik = pd.concat([paik, bd])
# Out:
# ./data\소상공인시장진흥공단_상가(상권)정보_강원_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_경기_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_경남_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_경북_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_광주_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_대구_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_대전_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_부산_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_서울_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_세종_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_울산_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_인천_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_전남_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_전북_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_제주_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_충남_202009.csv
# ./data\소상공인시장진흥공단_상가(상권)정보_충북_202009.csv

# %%
starbucks.to_csv('./results/스타벅스.csv', index=False)
coffeebean.to_csv('./results/커피빈.csv', index=False)
ediya.to_csv('./results/이디야.csv', index=False)
paik.to_csv('./results/빽다방.csv', index=False)

# %% [markdown]
# ## 도로명주소에서 광역시도와 시군구/행정구명 찾기

# %%
# 행정구
tmp_gu_dict = {
    '수원':['장안구', '권선구', '팔달구', '영통구'], 
    '성남':['수정구', '중원구', '분당구'], 
    '안양':['만안구', '동안구'], 
    '안산':['상록구', '단원구'], 
    '고양':['덕양구', '일산동구', '일산서구'], 
    '용인':['처인구', '기흥구', '수지구'], 
    '청주':['상당구', '서원구', '흥덕구', '청원구'], 
    '천안':['동남구', '서북구'], 
    '전주':['완산구', '덕진구'], 
    '포항':['남구', '북구'], 
    '창원':['의창구', '성산구', '진해구', '마산합포구', '마산회원구']
}

# %%
tmp_gu_dict.keys()
# Out:
# dict_keys(['수원', '성남', '안양', '안산', '고양', '용인', '청주', '천안', '전주', '포항', '창원'])

# %%
def split_addr(dfarg):
    metro, city = [], []
    for i in dfarg.index:
        addr = str(dfarg['도로명주소'][i]).split()
        metro.append(addr[0])
        if (addr[1][:2] in tmp_gu_dict.keys()):
            city.append(addr[2])
        else:
            city.append(addr[1])
    dfarg['광역시도'] = metro
    dfarg['시군구'] = city
    return dfarg

# %%
starbucks = split_addr(starbucks)
coffeebean = split_addr(coffeebean)
ediya = split_addr(ediya)
paik = split_addr(paik)

# %%
def get_ID(dfarg):
    si_name = [None] * len(dfarg)
    for n in dfarg.index:
        if dfarg['광역시도'][n][-3:] not in ['광역시', '특별시', '자치시']:
        
            # 같은 '시도' 이름을 가지는 고성 지역 처리
            if dfarg['시군구'][n].strip()[:-1]=='고성' and dfarg['광역시도'][n]=='강원도':
                si_name[n] = '고성(강원)'
            elif dfarg['시군구'][n].strip()[:-1]=='고성' and dfarg['광역시도'][n]=='경상남도':
                si_name[n] = '고성(경남)'
            else:
                si_name[n] = dfarg['시군구'][n].strip()[:-1] 
        
            # 광역시가 아니면서 구를 가지고 있는 시 처리 
            for keys, values in tmp_gu_dict.items():
                if len(dfarg['시군구'][n]) >= 5 and dfarg['시군구'][n].strip()[:2] in keys:
                    if len(dfarg['시군구'][n].split()[1]) == 2:
                        si_name[n] = keys + ' ' + dfarg['시군구'][n].split()[1]
                    elif dfarg['시군구'][n] in ['마산합포구','마산회원구']:
                        si_name[n] = keys + ' ' + dfarg['시군구'][n].strip()[2:-1]
                    else:
                        si_name[n] = keys + ' ' + dfarg['시군구'][n].strip()[4:-1]
        
        elif dfarg['광역시도'][n] == '세종특별자치시':  # 세종자치시의 경우는 세종으로
            si_name[n] = '세종'
        
        else:  # tmp_gu_dict와 세종을 제외한 나머지 지역 처리 
            if len(dfarg['시군구'][n].strip()) >= 3:
                si_name[n] = dfarg['광역시도'][n][:2] + ' ' + dfarg['시군구'][n][:-1]
            else:   # 인천 미추홀구 
                if dfarg['시군구'][n] == '남구' and dfarg['광역시도'][n] == '인천광역시':
                    si_name[n] = '인천 미추홀'
                else:
                    si_name[n] = dfarg['광역시도'][n][:2] + ' ' + dfarg['시군구'][n]
        
    return si_name

# %%
starbucks.reset_index(inplace=True)
starbucks.drop('index', axis=1, inplace=True)
starbucks.head()
# Out:
#     상호명        지점명                   도로명주소          경도         위도 광역시도  시군구
# 0  스타벅스        NaN       강원도 원주시 금불1길 28-5  127.931032  37.348466  강원도  원주시
# 1  스타벅스    오션월드2호점     강원도 홍천군 서면 한치골길 262  127.687273  37.652324  강원도  홍천군
# 2  스타벅스  대명델피노리조트점  강원도 고성군 토성면 미시령옛길 1153  128.493408  38.213128  강원도  고성군
# 3  스타벅스        강대점     강원도 춘천시 서부대성로 243-1  127.745087  37.872760  강원도  춘천시
# 4  스타벅스     속초중앙로점         강원도 속초시 중앙로 123  128.589463  38.202621  강원도  속초시

# %%
starbucks['ID'] = get_ID(starbucks)
starbucks['브랜드명'] = '스타벅스'
starbucks['스타벅스 매장수'] = 1
starbucks.head()
# Out:
#     상호명        지점명                   도로명주소          경도         위도 광역시도  시군구  \
# 0  스타벅스        NaN       강원도 원주시 금불1길 28-5  127.931032  37.348466  강원도  원주시
# 1  스타벅스    오션월드2호점     강원도 홍천군 서면 한치골길 262  127.687273  37.652324  강원도  홍천군
# 2  스타벅스  대명델피노리조트점  강원도 고성군 토성면 미시령옛길 1153  128.493408  38.213128  강원도  고성군
# 3  스타벅스        강대점     강원도 춘천시 서부대성로 243-1  127.745087  37.872760  강원도  춘천시
# 4  스타벅스     속초중앙로점         강원도 속초시 중앙로 123  128.589463  38.202621  강원도  속초시
#
#        ID  브랜드명  스타벅스 매장수
# 0      원주  스타벅스         1
# 1      홍천  스타벅스         1
# 2  고성(강원)  스타벅스         1
# 3      춘천  스타벅스         1
# 4      속초  스타벅스         1

# %%
coffeebean.reset_index(inplace=True)
coffeebean.drop('index', axis=1, inplace=True)
coffeebean['ID'] = get_ID(coffeebean)
coffeebean['브랜드명'] = '커피빈'
coffeebean['커피빈 매장수'] = 1
coffeebean.head()
# Out:
#    상호명          지점명                    도로명주소          경도         위도 광역시도  시군구  \
# 0  커피빈          NaN          강원도 동해시 일출로 107  129.118963  37.552715  강원도  동해시
# 1  커피빈  코리아원주AK플라자점            강원도 원주시 봉화로 1  127.927626  37.345679  강원도  원주시
# 2  커피빈          곰씨네  강원도 춘천시 동내면 춘천순환로 61-15  127.751359  37.856311  강원도  춘천시
# 3  커피빈          NaN           경기도 이천시 남천로 93  127.447687  37.276730  경기도  이천시
# 4  커피빈     코리아수원인계점      경기도 수원시 팔달구 권광로 195  127.032669  37.264938  경기도  팔달구
#
#    ID 브랜드명  커피빈 매장수
# 0  동해  커피빈        1
# 1  원주  커피빈        1
# 2  춘천  커피빈        1
# 3  이천  커피빈        1
# 4  팔달  커피빈        1

# %%
ediya.reset_index(inplace=True)
ediya.drop('index', axis=1, inplace=True)
ediya['ID'] = get_ID(ediya)
ediya['브랜드명'] = '이디야'
ediya['이디야 매장수'] = 1
ediya.head()
# Out:
#         상호명     지점명                      도로명주소          경도         위도 광역시도  \
# 0     이디야커피    우두동점             강원도 춘천시 충열로 39  127.732714  37.899493  강원도
# 1     이디야커피   철원와수점  강원도 철원군 서면 와수로181번길 25-21  127.438109  38.239147  강원도
# 2     이디야커피    하이원점     강원도 정선군 고한읍 하이원길 265-1  128.827807  37.209488  강원도
# 3  이디야에스프레소     NaN        강원도 춘천시 시청길10번길 4-1  127.728578  37.880075  강원도
# 4     이디야커피  춘천애막골점        강원도 춘천시 후석로186번길 18  127.754289  37.867310  강원도
#
#    시군구  ID 브랜드명  이디야 매장수
# 0  춘천시  춘천  이디야        1
# 1  철원군  철원  이디야        1
# 2  정선군  정선  이디야        1
# 3  춘천시  춘천  이디야        1
# 4  춘천시  춘천  이디야        1

# %%
paik.reset_index(inplace=True)
paik.drop('index', axis=1, inplace=True)
paik['ID'] = get_ID(paik)
paik['브랜드명'] = '빽다방'
paik['빽다방 매장수'] = 1
paik.head()
# Out:
#    상호명       지점명                도로명주소          경도         위도 광역시도  시군구  ID  \
# 0  빽다방       NaN   강원도 원주시 무실로12번길 33  127.947781  37.350006  강원도  원주시  원주
# 1  빽다방  춘천석사CGV점       강원도 춘천시 지석로 85  127.744832  37.851125  강원도  춘천시  춘천
# 2  빽다방     강릉금학점      강원도 강릉시 신대학길 14  128.894954  37.752800  강원도  강릉시  강릉
# 3  빽다방    삼척대학로점     강원도 삼척시 대학로 23-8  129.163077  37.443281  강원도  삼척시  삼척
# 4  빽다방   원주단구GS점  강원도 원주시 남원로534번길 20  127.948675  37.330389  강원도  원주시  원주
#
#   브랜드명  빽다방 매장수
# 0  빽다방        1
# 1  빽다방        1
# 2  빽다방        1
# 3  빽다방        1
# 4  빽다방        1

# %%
starbucks.to_csv('./results/스타벅스2.csv', index=False)
coffeebean.to_csv('./results/커피빈2.csv', index=False)
ediya.to_csv('./results/이디야2.csv', index=False)
paik.to_csv('./results/빽다방2.csv', index=False)

# %% [markdown]
# ## 브랜드별 피벗 테이블 생성

# %%
pt_sb = starbucks.pivot_table('스타벅스 매장수', index='ID', aggfunc='sum')
pt_sb = pt_sb.reset_index()
print(len(pt_sb))
pt_sb.head()
# Out:
# 191
#    ID  스타벅스 매장수
# 0  강릉         5
# 1  거제         5
# 2  경기         2
# 3  경산         8
# 4  경주         8

# %%
pt_cb = coffeebean.pivot_table('커피빈 매장수', index='ID', aggfunc='sum')
pt_cb = pt_cb.reset_index()
print(len(pt_cb))
pt_cb.head()
# Out:
# 99
#       ID  커피빈 매장수
# 0     경주        2
# 1  광주 남구        2
# 2  광주 동구        1
# 3  광주 서구        1
# 4     구리        1

# %%
pt_ed = ediya.pivot_table('이디야 매장수', index='ID', aggfunc='sum')
pt_ed = pt_ed.reset_index()
print(len(pt_ed))
pt_ed.head()
# Out:
# 235
#    ID  이디야 매장수
# 0  가평        8
# 1  강릉       15
# 2  강진        1
# 3  거제        7
# 4  거창        1

# %%
pt_bd = paik.pivot_table('빽다방 매장수', index='ID', aggfunc='sum')
pt_bd = pt_bd.reset_index()
print(len(pt_bd))
pt_bd.head()
# Out:
# 147
#        ID  빽다방 매장수
# 0      강릉        2
# 1      거창        1
# 2      경산        3
# 3      경주        2
# 4  고성(경남)        2

# %% [markdown]
# ## 카페 데이터 병합

# %%
coffee = pd.merge(pt_ed, pt_sb, how='left', on='ID')
coffee.head()
# Out:
#    ID  이디야 매장수  스타벅스 매장수
# 0  가평        8       NaN
# 1  강릉       15       5.0
# 2  강진        1       NaN
# 3  거제        7       5.0
# 4  거창        1       NaN

# %%
coffee = pd.merge(coffee, pt_cb, how='left', on='ID')
coffee = pd.merge(coffee, pt_bd, how='left', on='ID')
coffee.head()
# Out:
#    ID  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수
# 0  가평        8       NaN      NaN      NaN
# 1  강릉       15       5.0      NaN      2.0
# 2  강진        1       NaN      NaN      NaN
# 3  거제        7       5.0      NaN      NaN
# 4  거창        1       NaN      NaN      1.0

# %%
coffee = coffee.fillna(0)
coffee.head()
# Out:
#    ID  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수
# 0  가평        8       0.0      0.0      0.0
# 1  강릉       15       5.0      0.0      2.0
# 2  강진        1       0.0      0.0      0.0
# 3  거제        7       5.0      0.0      0.0
# 4  거창        1       0.0      0.0      1.0

# %%
coffee['스타벅스 매장수'] = coffee['스타벅스 매장수'].astype(int)
coffee['커피빈 매장수'] = coffee['커피빈 매장수'].astype(int)
coffee['빽다방 매장수'] = coffee['빽다방 매장수'].astype(int)

# %%
coffee['커피지수'] = (coffee['스타벅스 매장수']+coffee['커피빈 매장수']) / \
                        (coffee['이디야 매장수']+coffee['빽다방 매장수'])
coffee.tail()
# Out:
#      ID  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수      커피지수
# 230  홍천        3         2        0        1  0.500000
# 231  화성       26        19        5       11  0.648649
# 232  화천        1         0        0        0  0.000000
# 233  횡성        1         0        0        0  0.000000
# 234  흥덕       13        10        1        4  0.647059

# %%
coffee.to_csv('./results/커피피봇테이블.csv', index=False)

# %% [markdown]
# ## 카토그램과 커피 데이터 합치기

# %%
df = pd.read_csv('./results/03.pop.csv', index_col = 0)
df.head()
# Out:
#   광역시도  시군구  20~39세계  20~39세여자  65세이상계    인구수계   인구수남자   인구수여자      소멸비율  \
# 0   강원  강릉시    46008     20993   40497  203057  101154  101903  1.036768
# 1   강원  고성군     4006      1699    7005   23621   11933   11688  0.485082
# 2   강원  동해시    16311      7510   16152   83888   42093   41795  0.929916
# 3   강원  삼척시    12428      5280   14953   61833   31630   30203  0.706213
# 4   강원  속초시    15928      7411   14010   76302   37488   38814  1.057959
#
#    소멸위기지역      ID  y   x       여성비   2030여성비
# 0       0      강릉  3  11  0.184431 -4.370979
# 1       1  고성(강원)  0  10 -0.518606 -7.588617
# 2       1      동해  4  11 -0.177618 -3.957452
# 3       1      삼척  5  11 -1.153915 -7.515288
# 4       0      속초  1  10  0.868916 -3.471873

# %%
df = df[['ID', 'y', 'x']]
df.head()
# Out:
#        ID  y   x
# 0      강릉  3  11
# 1  고성(강원)  0  10
# 2      동해  4  11
# 3      삼척  5  11
# 4      속초  1  10

# %%
coffee_index = pd.merge(df, coffee, how='left', on='ID')
coffee_index = coffee_index.fillna(0)
coffee_index.head()
# Out:
#        ID  y   x  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수      커피지수
# 0      강릉  3  11     15.0       5.0      0.0      2.0  0.294118
# 1  고성(강원)  0  10      1.0       2.0      0.0      0.0  2.000000
# 2      동해  4  11      1.0       1.0      1.0      1.0  1.000000
# 3      삼척  5  11      1.0       1.0      0.0      2.0  0.333333
# 4      속초  1  10      8.0       4.0      0.0      0.0  0.500000

# %%
coffee_index.to_csv('./results/커피지수.csv', index=False)

# %% [markdown]
# ## 커피지수 카토그램 그리기

# %%
BORDER_LINES = [
    [(5, 1), (5,2), (6,2), (6,3), (11,3), (11,0)], # 인천
    [(5,4), (5,5), (2,5), (2,7), (4,7), (4,9), (7,9), 
     (7,7), (9,7), (9,5), (10,5), (10,4), (5,4)], # 서울
    [(1,7), (1,8), (3,8), (3,10), (10,10), (10,7), 
     (12,7), (12,6), (11,6), (11,5), (12, 5), (12,4), 
     (11,4), (11,3)], # 경기도
    [(8,10), (8,11), (6,11), (6,12)], # 강원도
    [(12,5), (13,5), (13,4), (14,4), (14,5), (15,5), 
     (15,4), (16,4), (16,2)], # 충청북도
    [(16,4), (17,4), (17,5), (16,5), (16,6), (19,6), 
     (19,5), (20,5), (20,4), (21,4), (21,3), (19,3), (19,1)], # 전라북도
    [(13,5), (13,6), (16,6)], # 대전시
    [(13,5), (14,5)], #세종시
    [(21,2), (21,3), (22,3), (22,4), (24,4), (24,2), (21,2)], #광주
    [(20,5), (21,5), (21,6), (23,6)], #전라남도
    [(10,8), (12,8), (12,9), (14,9), (14,8), (16,8), (16,6)], #충청북도
    [(14,9), (14,11), (14,12), (13,12), (13,13)], #경상북도
    [(15,8), (17,8), (17,10), (16,10), (16,11), (14,11)], #대구
    [(17,9), (18,9), (18,8), (19,8), (19,9), (20,9), (20,10), (21,10)], #부산
    [(16,11), (16,13)], #울산
    [(27,5), (27,6), (25,6)],
]

# %%
def drawKorea(targetData, blockedMap, cmapname):
    gamma = 0.75

    whitelabelmin = (max(blockedMap[targetData]) - 
                     min(blockedMap[targetData]))*0.25 + \
                     min(blockedMap[targetData])

    datalabel = targetData

    vmin = min(blockedMap[targetData])
    vmax = max(blockedMap[targetData])

    mapdata = blockedMap.pivot_table(index='y', columns='x', values=targetData)
    masked_mapdata = np.ma.masked_where(np.isnan(mapdata), mapdata)
    
    plt.figure(figsize=(9, 11))
    plt.pcolor(masked_mapdata, vmin=vmin, vmax=vmax, cmap=cmapname, 
               edgecolor='#aaaaaa', linewidth=0.5)

    # 지역 이름 표시
    for idx, row in blockedMap.iterrows():
        # 광역시는 구 이름이 겹치는 경우가 많아서 광역시 이름도 같이 표시 
        if len(row.ID.split())==2:
            dispname = f'{row.ID.split()[0]}\n{row.ID.split()[1]}'
        elif row.ID[:2]=='고성':
            dispname = '고성'
        else:
            dispname = row.ID

        # 서대문구, 서귀포시 같이 이름이 3자 이상인 경우에 작은 글자로 표시
        if len(dispname.splitlines()[-1]) >= 3:
            fontsize, linespacing = 10.0, 1.1
        else:
            fontsize, linespacing = 11, 1.

        annocolor = 'white' if row[targetData] > whitelabelmin else 'black'
        plt.annotate(dispname, (row['x']+0.5, row['y']+0.5), weight='bold',
                     fontsize=fontsize, ha='center', va='center', color=annocolor,
                     linespacing=linespacing)

    # 시도 경계 표시
    for path in BORDER_LINES:
        ys, xs = zip(*path)
        plt.plot(xs, ys, c='black', lw=2)

    plt.gca().invert_yaxis()

    plt.axis('off')

    cb = plt.colorbar(shrink=.1, aspect=10)
    cb.set_label(datalabel)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 커피지수

# %%
drawKorea('커피지수', coffee_index, 'Reds')

# %%
# 커피지수 Top 10
coffee_index.sort_values(by='커피지수', ascending=False).head(10)
# Out:
#          ID   y   x  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수      커피지수
# 116   대구 서구  15   8      1.0       3.0      0.0      0.0  3.000000
# 154   서울 서초   7   6     21.0      49.0     31.0      7.0  2.857143
# 140   서울 강남   8   6     47.0      87.0     69.0     12.0  2.644068
# 139  부산 해운대  17  12     11.0      29.0      5.0      2.0  2.615385
# 162   서울 종로   4   6     15.0      33.0     15.0      5.0  2.400000
# 163   서울 중구   5   6     23.0      57.0     15.0      7.0  2.400000
# 117   대구 수성  14  10      9.0      23.0      2.0      2.0  2.272727
# 19       과천   7   7      1.0       4.0      0.0      1.0  2.000000
# 43       연천   1   5      1.0       0.0      2.0      0.0  2.000000
# 1    고성(강원)   0  10      1.0       2.0      0.0      0.0  2.000000

# %% [markdown]
# ### 스타벅스 매장수

# %%
drawKorea('스타벅스 매장수', coffee_index, 'Greens')

# %%
# 스타벅스 매장수 Top 5
coffee_index.sort_values(by='스타벅스 매장수', ascending=False).head()
# Out:
#         ID  y  x  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수      커피지수
# 140  서울 강남  8  6     47.0      87.0     69.0     12.0  2.644068
# 163  서울 중구  5  6     23.0      57.0     15.0      7.0  2.400000
# 154  서울 서초  7  6     21.0      49.0     31.0      7.0  2.857143
# 157  서울 송파  6  8     28.0      34.0     13.0     10.0  1.236842
# 162  서울 종로  4  6     15.0      33.0     15.0      5.0  2.400000

# %% [markdown]
# ### 커피빈 매장수

# %%
drawKorea('커피빈 매장수', coffee_index, 'Blues')

# %%
# 커피빈 매장수 Top 5
coffee_index.sort_values(by='커피빈 매장수', ascending=False).head()
# Out:
#          ID  y  x  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수      커피지수
# 140   서울 강남  8  6     47.0      87.0     69.0     12.0  2.644068
# 154   서울 서초  7  6     21.0      49.0     31.0      7.0  2.857143
# 162   서울 종로  4  6     15.0      33.0     15.0      5.0  2.400000
# 163   서울 중구  5  6     23.0      57.0     15.0      7.0  2.400000
# 159  서울 영등포  8  4     27.0      30.0     13.0      5.0  1.343750

# %% [markdown]
# ### 이디야 매장수

# %%
drawKorea('이디야 매장수', coffee_index, 'Oranges')

# %%
# 이디야 매장수 Top 5
coffee_index.sort_values(by='이디야 매장수', ascending=False).head()
# Out:
#         ID   y  x  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수      커피지수
# 140  서울 강남   8  6     47.0      87.0     69.0     12.0  2.644068
# 143  서울 강서   6  4     47.0      19.0      6.0      8.0  0.454545
# 27     남양주   2  7     46.0      12.0      1.0      3.0  0.265306
# 173  인천 남동  10  2     35.0      13.0      1.0     13.0  0.291667
# 33      부천   5  2     33.0       7.0      7.0      9.0  0.333333

# %% [markdown]
# ### 빽다방 매장수

# %%
drawKorea('빽다방 매장수', coffee_index, 'PuRd')

# %%
# 빽다방 매장수 Top 5
coffee_index.sort_values(by='빽다방 매장수', ascending=False).head()
# Out:
#         ID   y  x  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수      커피지수
# 173  인천 남동  10  2     35.0      13.0      1.0     13.0  0.291667
# 140  서울 강남   8  6     47.0      87.0     69.0     12.0  2.644068
# 59      화성   9  3     26.0      19.0      5.0     11.0  0.648649
# 121  대전 서구  16  4     12.0      25.0      2.0     10.0  1.227273
# 157  서울 송파   6  8     28.0      34.0     13.0     10.0  1.236842

# %% [markdown]
# ## 지도위에 표시하기

# %%
import folium
import json

# %%
coffee_index_folium = coffee_index.set_index('ID')
coffee_index_folium.head()
# Out:
#         y   x  이디야 매장수  스타벅스 매장수  커피빈 매장수  빽다방 매장수      커피지수
# ID
# 강릉      3  11     15.0       5.0      0.0      2.0  0.294118
# 고성(강원)  0  10      1.0       2.0      0.0      0.0  2.000000
# 동해      4  11      1.0       1.0      1.0      1.0  1.000000
# 삼척      5  11      1.0       1.0      0.0      2.0  0.333333
# 속초      1  10      8.0       4.0      0.0      0.0  0.500000

# %%
geo_path = './data/skorea_municipalities_geo_simple.json'
geo_data = json.load(open(geo_path, encoding='utf8'))

map = folium.Map(location=[35.9902, 127.054], zoom_start=7)
folium.Choropleth(geo_data = geo_data,
               data = coffee_index_folium['커피지수'],
               columns = [coffee_index_folium.index, coffee_index_folium['커피지수']],
               fill_color = 'YlGnBu',
               key_on = 'feature.id').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>커피지수</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[35.9902, 127.054], zoom_start=7)
folium.Choropleth(geo_data = geo_data,
               data = coffee_index_folium['스타벅스 매장수'],
               columns = [coffee_index_folium.index, coffee_index_folium['스타벅스 매장수']],
               fill_color = 'Greens',
               key_on = 'feature.id').add_to(map)
title_html = '<h3 align="center" style="font-size:20px"><b>스타벅스 매장수</b></h3>'   
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
