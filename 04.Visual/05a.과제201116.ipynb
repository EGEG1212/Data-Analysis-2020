# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline  #매직명령어 노트북내부에그림표시
# Out:
# UsageError: unrecognized arguments: #매직명령어 노트북내부에그림표시

# %%
mpl.rc('font', family='Malgun Gothic') # 한글폰트 설정
mpl.rc('axes', unicode_minus=False) # 유니코드에서  음수 부호설정

# %% [markdown]
# 소상공인 시장 진흥공단에서 제공하는 2년 2017.10-2019.09 국내의 카페 업소 수 데이터.CSV
# ### 1. matplotlib를 이용하여 월별 카페의 개수를 나타내는 막대그래프Bar(단, x축간격 3개월)

# %%
a = pd.read_csv('cafe_2year.csv')

# %%
b =a.set_index('기준월')

# %%
b[2::3].plot.bar(rot=0)
plt.xlabel('년 월')
plt.ylabel('카페 수')
plt.ylim(76923, 100000)
plt.title('전국의 월별 카페 수', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
df= pd.read_csv('cafe_2year.csv')
df.head()
# Out:
#       기준월    카페수
# 0  201710  79296
# 1  201711  80738
# 2  201712  76923
# 3  201801  77942
# 4  201802  84967

# %%
df.tail()
# Out:
#        기준월    카페수
# 19  201905  97740
# 20  201906  98217
# 21  201907  98311
# 22  201908  98538
# 23  201909  98779

# %%
df.describe()
# Out:
#                  기준월           카페수
# count      24.000000     24.000000
# mean   201831.500000  89068.416667
# std        65.900452   7996.554529
# min    201710.000000  76923.000000
# 25%    201803.750000  81120.500000
# 50%    201809.500000  88896.000000
# 75%    201903.250000  97416.500000
# max    201909.000000  98779.000000

# %%
df['datetime'] = df['기준월'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m'))

# %%
df.head()
# Out:
#       기준월    카페수   datetime
# 0  201710  79296 2017-10-01
# 1  201711  80738 2017-11-01
# 2  201712  76923 2017-12-01
# 3  201801  77942 2018-01-01
# 4  201802  84967 2018-02-01

# %%
#0부터 세기때문에 datetime으로 인덱스 지정
df.set_index(df['datetime'], inplace=True)
df.head()
# Out:
#                기준월    카페수   datetime
# datetime
# 2017-10-01  201710  79296 2017-10-01
# 2017-11-01  201711  80738 2017-11-01
# 2017-12-01  201712  76923 2017-12-01
# 2018-01-01  201801  77942 2018-01-01
# 2018-02-01  201802  84967 2018-02-01

# %%
df = df.drop('datetime', 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-38b587379c4f> in <module>
# ----> 1 df = df.drop('datetime', 1)
#       2 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df.tail()
# Out:
#                기준월    카페수
# datetime
# 2019-05-01  201905  97740
# 2019-06-01  201906  98217
# 2019-07-01  201907  98311
# 2019-08-01  201908  98538
# 2019-09-01  201909  98779

# %%
range = pd.date_range('2017-10-01', '2019-09-01', freq='3M')
df_1m = pd.DataFrame(index=range)

# %%
df_1m['amount'] =
# Out:
# Empty DataFrame
# Columns: []
# Index: [2017-10-31 00:00:00, 2018-01-31 00:00:00, 2018-04-30 00:00:00, 2018-07-31 00:00:00, 2018-10-31 00:00:00, 2019-01-31 00:00:00, 2019-04-30 00:00:00, 2019-07-31 00:00:00]

# %%
plt.figure(figsize=(12,5))
sns.barplot(x="기준월", y="카페수", data=df)
plt.title("전국의 월별 카페수")
plt.show()

# %% [markdown]
# 건강보험 심사평가원에서 제공(2019.09기준)하는 전국의 종합병원의
# 일반의, 인턴, 레지던트, 전문의 의사 수의 데이터.CSV (doctor_2019.csv)
#
# ### 2. CSV파일을 읽어서 서울과 6개의 광역시(부산, 대구, 인천, 대전, 광주, 울산)에 대해 지역, 일반의, 인턴, 레지던트, 전문의 의사 수를 출력

# %%
c = pd.read_csv('doctor2.csv')
d = c.set_index('지역')

# %%
d
# Out:
#     일반의 수  인턴 수  레지던트 수  전문의 수
# 지역
# 서울    162  1196    4757   9375
# 부산     58   197     785   2211
# 대구     27   215     712   1436
# 인천     47   138     444   1518
# 대전     25   142     425   1006
# 광주     16   102     356   1006
# 울산     19    23     104    467

# %% [markdown]
# ### 3. 2번문제의 결과를 doctor2.csv파일로 저장

# %%
d.to_csv('doctor2.csv')
d
# Out:
#     일반의 수  인턴 수  레지던트 수  전문의 수
# 지역
# 서울    162  1196    4757   9375
# 부산     58   197     785   2211
# 대구     27   215     712   1436
# 인천     47   138     444   1518
# 대전     25   142     425   1006
# 광주     16   102     356   1006
# 울산     19    23     104    467

# %%
f = pd.read_csv('doctor2.csv')
f
# Out:
#    지역  일반의 수  인턴 수  레지던트 수  전문의 수
# 0  서울    162  1196    4757   9375
# 1  부산     58   197     785   2211
# 2  대구     27   215     712   1436
# 3  인천     47   138     444   1518
# 4  대전     25   142     425   1006
# 5  광주     16   102     356   1006
# 6  울산     19    23     104    467

# %%
g = f.set_index('지역')
g
# Out:
#     일반의 수  인턴 수  레지던트 수  전문의 수
# 지역
# 서울    162  1196    4757   9375
# 부산     58   197     785   2211
# 대구     27   215     712   1436
# 인천     47   138     444   1518
# 대전     25   142     425   1006
# 광주     16   102     356   1006
# 울산     19    23     104    467

# %% [markdown]
# ### 4. doctor2.csv를 읽어 서울과 6개 광역시의 종합 병원 전문의 의사 수를 산포 그래프(scatter plot)로 표현

# %%
plt.scatter(g.index,g['전문의 수'])
plt.title('서울 및 광역시 종합병원 전문의 수', loc='center', pad=10, fontsize=16, color='g')
plt.xlabel('시')
plt.ylabel('의사 수')
plt.show()

# %% [markdown]
# ### 5. doctor2.csv파일을 읽어 서울과 6개 광역시의 종합병원의 일반의, 인턴, 레지던트, 전문의 의사 수를 선 그래프로

# %%
plt.plot(g.index, g['일반의 수'], 'ro-',label="일반의")
plt.plot(g.index, g['인턴 수'], 'bo-',label="인턴")
plt.plot(g.index, g['레지던트 수'], 'yo-',label="레지던트")
plt.plot(g.index, g['전문의 수'], 'mo-',label="전문의")
plt.title('서울 및 광역시 종합병원 전문의 수', loc='center', pad=10, fontsize=16, color='g')
plt.xlabel('시')
plt.ylabel('의사 수')
plt.legend()
plt.show()

# %%
# 이방법으로 만들면 이름, 색깔, 형태등 변경이 어려운 것 같다.
g.plot()
plt.show()

# %% [markdown]
# ### 6. doctor2.csv파일을 읽어 서울 종합병원의 의사 수 분포를 의사 유형별로 나타내는 파이그래프

# %%
labels = ['일반의', '인턴', '레지던트', '전문의']
plt.pie(g.loc['서울'],autopct='%.2f%%',labels=labels,startangle=90,explode=explode)
plt.axis('equal')
plt.title('서울 및 광역시 종합병원 의사 유형별 분포', loc='center', pad=10, fontsize=16, color='g')
plt.show()

# %%
explode = [0, 0.05, 0, 0]
g.loc['서울'].plot.pie(autopct='%.2f%%',startangle=90,explode=explode)
plt.title('서울 및 광역시 종합병원 의사 유형별 분포', loc='center', pad=10, fontsize=16, color='g')
plt.axis('equal')
plt.show()

# %%
g.loc['서울']
# Out:
# 일반의 수      162
# 인턴 수      1196
# 레지던트 수    4757
# 전문의 수     9375
# Name: 서울, dtype: int64
